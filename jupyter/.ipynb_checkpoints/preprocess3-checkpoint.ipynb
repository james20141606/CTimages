# %%
# %matplotlib inline
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import scipy.ndimage
from skimage import measure, morphology
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import h5py

# %%
cd /Share/home/chenxupeng/projects/pr/preprocess/
# Out:
# /Share/home/chenxupeng/projects/pr/preprocess

# %%
f = h5py.File('processed_tensor_1')

# %%
sample = f['preprocessLKDS-00001'][:,:,:]

# %%
sample.shape
# Out:
# (281, 512, 512)

# %%
imshow(sample[200],cmap = cm.bone)

# %%
old_spacing = np.loadtxt('spacing/spacing_info_1.txt')

# %%
old_spacing[0]/[1,1,1]
# Out:
# array([ 0.806641,  0.806641,  1.25    ])

# %%
def resample(image, old_spacing, new_spacing=[1,1,1]):
    resize_factor = old_spacing / new_spacing
    new_real_shape = image.shape * resize_factor
    new_shape = np.round(new_real_shape)
    real_resize_factor = new_shape / image.shape
    new_spacing = old_spacing / real_resize_factor
    image = scipy.ndimage.interpolation.zoom(image, real_resize_factor, mode='nearest')
    return image, new_spacing

# %%
img, spa = resample(sample, old_spacing[0], new_spacing=[1,1,1])

# %%
img.shape
# Out:
# (227, 413, 640)

# %%
sample.shape
# Out:
# (281, 512, 512)

# %%
def plot_3d(image, threshold = -300):
    # Position the scan upright,
    # so the head of the patient would be at the top facing the camera
    p = image.transpose(2,1,0)
    verts = measure.marching_cubes(p, level = threshold)
    
    faces = verts[3].astype('int')
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111, projection='3d')
    # Fancy indexing: `verts[faces]` to generate a collection of triangles
    mesh = Poly3DCollection(verts[faces], alpha=0.1)
    face_color = [0.5, 0.5, 1]
    mesh.set_facecolor(face_color)
    ax.add_collection3d(mesh)
    ax.set_xlim(0, p.shape[0])
    ax.set_ylim(0, p.shape[1])
    ax.set_zlim(0, p.shape[2])
    plt.show()

# %%
plot_3d(img,-300)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-133-46c415808355> in <module>()
# ----> 1 plot_3d(img,-300)
#
# <ipython-input-132-664e77fbc36a> in plot_3d(image, threshold)
#       9     ax = fig.add_subplot(111, projection='3d')
#      10     # Fancy indexing: `verts[faces]` to generate a collection of triangles
# ---> 11     mesh = Poly3DCollection(verts[faces], alpha=0.1)
#      12     face_color = [0.5, 0.5, 1]
#      13     mesh.set_facecolor(face_color)
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
p = img.transpose(2,1,0)
t =measure.marching_cubes(p, level = -400)

# %%
t[0].shape
# Out:
# (624737, 3)

# %%
t[2].shape
# Out:
# (624737, 3)

# %%
t[1].shape
# Out:
# (1241098, 3)

# %%
t[3].shape
# Out:
# (624737,)

# %%
t[3].astype('int')
# Out:
# array([765, 918, 840, ..., 486, 505, 600])
